# %%
import matplotlib.pyplot as plt
from numpy.random import RandomState
from sklearn import cluster, decomposition
from sklearn.datasets import fetch_olivetti_faces
from matplotlib import pyplot as plt

import PIL.Image
import numpy as np

# %%
image = PIL.Image.open("PIL.jpeg")

# %%
print(image.size)
# Out:
# (312, 270)

# %%
faces, _ = fetch_olivetti_faces(return_X_y=True, shuffle=True, random_state=11)
n_samples, n_features = faces.shape

# %%
faces.shape
# Out:
# (400, 4096)

# %%
X = image

# %%
18* 15
# Out:
# 270

# %%
plt.imshow(image)
plt.show()

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\hp\onedrive\pictures\conda\lib\site-packages (9.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
width, height = image.size
print(f"Image size: {width}x{height}")
image.show()

img_array = np.array(image)
# Out:
# Image size: 312x270

# %%
img_array.shape
# Out:
# (270, 312, 3)

# %%
270+312+3
# Out:
# 585

# %%
img_array.shape
# Out:
# (270, 312, 3)

# %%
plt.imshow(img_array)

# %%
X_new = np.asarray(X)

# %%
X_new2 = X_new.reshape(-1, 270 +312+ 3)

# %%
pca = decomposition.PCA(0.9)
pca.fit(X_new2)
# Out:
# PCA(n_components=0.9)

# %%
X_trans = pca.transform(X_new2)

# %%
270 + 312+ 3
# Out:
# 585

# %%
X_new2.shape, X_trans.shape
# Out:
# ((432, 585), (432, 31))

# %%
X_reverse = pca.inverse_transform(X_trans)

# %%
X_reverse.shape, X_trans.shape
# Out:
# ((432, 585), (432, 31))

# %%
plt.imshow(X_reverse.reshape((270, 312, 3)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pca.n_components_
# Out:
# 66

# %%
X_reverse = pca.inverse_transform(X)

# %%
X_reverse.shape
# Out:
# (400, 4096)

# %%
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(121).imshow(
    faces[0].reshape((64, 64))
)
fig.add_subplot(122).imshow(
    X_reverse[0].reshape((64, 64))
)
